# %%
import numpy as np
import pandas as pd
from pandas import DataFrame, Series
% matplotlib inline
from matplotlib import pyplot as plt

# %%
schools_df = pd.read_csv("~/Downloads/NYC_SchoolLocations.txt")

# %%
schools_df.head()
# Out:
#   FID      ATS_CODE BORO  BORONUM LOC_CODE              SCHOOLNAME  \
# 0   0  15K001          K        2     K001     P.S. 001 THE BERGEN
# 1   1  17K002          K        2     K002                M.S. 002
# 2   2  21K095          K        2     K095  P.S. 095 THE GRAVESEND
# 3   3  21K096          K        2     K096       I.S. 096 SETH LOW
# 4   4  21K097          K        2     K097    P.S. 97 THE HIGHLAWN
#
#                           SCH_TYPE  MANAGED_BY  GEO_DISTRI  ADMIN_DIST  \
# 0                       Elementary           1          15          15
# 1  Junior High-Intermediate-Middle           1          17          17
# 2                              K-8           1          21          21
# 3  Junior High-Intermediate-Middle           1          21          21
# 4                       Elementary           1          21          21
#
#                   ADDRESS STATE_CODE                     ZIP  \
# 0           309 47 STREET         NY  11,220.000000000000000
# ...

# %%
schools_df[schools_df.SCHOOLNAME.apply(lambda x: 'Academic' in x)]
# Out:
#         FID ATS_CODE BORO  BORONUM LOC_CODE  \
# 1576  1,576   07X491    X        2     X491
#
#                               SCHOOLNAME    SCH_TYPE  MANAGED_BY  GEO_DISTRI  \
# 1576  Academic Leadership Charter School  Elementary           2           7
#
#       ADMIN_DIST              ADDRESS STATE_CODE                     ZIP  \
# 1576          84  677 EAST 141 STREET         NY  10,454.000000000000000
#
#           PRINCIPAL       PRIN_PH           FAX    GRADES   City   POINT_X  \
# 1576  Norma Hurwitz  718-585-4215  718-585-4837  0K,01,02  BRONX -73.91297
#
#         POINT_Y
# 1576  40.807685
