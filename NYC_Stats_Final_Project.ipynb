# %%
import numpy as np
import pandas as pd
from pandas import DataFrame, Series
from matplotlib import pyplot as plt
% matplotlib inline

# %%
felony_df = pd.read_csv("NYPD_7_Major_Felony_Incidents.csv")
felony_df.head()
# Out:
#    OBJECTID Identifier   Occurrence Date Day of Week Occurrence Month  \
# 0         1   f070032d    9/6/1940 19:30      Friday              Sep
# 1         2   c6245d4d   12/14/1968 0:20    Saturday              Dec
# 2         3   716dbc6f  10/30/1970 15:30      Friday              Oct
# 3         4   638cd7b7   7/18/1972 23:00     Tuesday              Jul
# 4         5   6e410287    5/21/1987 0:01    Thursday              May
#
#    Occurrence Day  Occurrence Year  Occurrence Hour  CompStat Month  \
# 0               6             1940               19               9
# 1              14             1968                0              12
# 2              30             1970               15              10
# 3              18             1972               23               7
# 4              21             1987                0               5
#
#    CompStat Day  CompStat Year                         Offense  \
# 0             7           2010                        BURGLARY
# ...

# %%
pop_df = pd.read_csv("New_York_City_Population_By_Boroughs.csv")
pop_df.head()
pop_df.describe()
# Out:
#        2000 Population  2010 Population
# count         5.000000           5.0000
# mean    1601655.600000     1635026.6000
# std      799574.689346      796289.5162
# min      443728.000000      468730.0000
# 25%     1332650.000000     1385108.0000
# 50%     1537195.000000     1585873.0000
# 75%     2229379.000000     2230722.0000
# max     2465326.000000     2504700.0000

# %%
school_df = pd.read_csv("School_Safety_Report.csv", parse_dates = ["School Year"])
school_df.head()
school_df.describe(include = 'all')
# Out:
#        School Year Building Code     DBN  \
# count         4242          4241    3563
# unique           3          1198    1894
# top        2013-14          X450  19K364
# freq          2159            21       3
# mean           NaN           NaN     NaN
# std            NaN           NaN     NaN
# min            NaN           NaN     NaN
# 25%            NaN           NaN     NaN
# 50%            NaN           NaN     NaN
# 75%            NaN           NaN     NaN
# max            NaN           NaN     NaN
#
#                                             Location Name Location Code  \
# count                                                4241          3563
# unique                                               2276          1850
# top     New Visions Charter High School for the Humani...          X695
# freq                                                    5             4
# mean                                                  NaN           NaN
# ...

# %%
for col in felony_df.columns:
    felony_df[col] = felony_df[col].astype(object)

felony_df.describe()
# Out:
#         OBJECTID Identifier Occurrence Date Day of Week Occurrence Month  \
# count    1048574    1048576         1048333     1048402          1048402
# unique   1048574    1048191          477239           7               12
# top      1048575   7.44E+07   1/1/2008 0:01      Friday              Aug
# freq           1          3              78      167341            96724
#
#         Occurrence Day  Occurrence Year  Occurrence Hour  CompStat Month  \
# count          1048402          1048333          1048333         1048575
# unique              31               61               24              12
# top                  1             2006               15               8
# freq             43121           127321            61489           96809
#
#         CompStat Day  CompStat Year        Offense Offense Classification  \
# count        1048575        1048575        1048575                1048575
# unique            31             10              6                      1
# ...
